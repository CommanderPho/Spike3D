# %%
# 2023-05-23 - This code was created to quickly backup all of the good `loadedSessPickle.pkl` files from the session folders into the './output' subfolder in the session:
# p: /nfs/turbo/umms-kdiba/Data/KDIBA/pin01/one/11-03_12-3-25/output/loadedSessPickle.pkl already in output folder.
# p: /nfs/turbo/umms-kdiba/Data/KDIBA/pin01/one/11-09_21-17-16/output/loadedSessPickle.pkl already in output folder.
# p: /nfs/turbo/umms-kdiba/Data/KDIBA/pin01/one/fet11-04_21-20-3/output/loadedSessPickle.pkl already in output folder.
# p: /nfs/turbo/umms-kdiba/Data/KDIBA/pin01/one/11-03_21-26-8/output/loadedSessPickle.pkl already in output folder.
# p: /nfs/turbo/umms-kdiba/Data/KDIBA/pin01/one/11-09_22-4-5/output/loadedSessPickle.pkl already in output folder.
# ...

# %%
# %config IPCompleter.use_jedi = False
# %load_ext autoreload
# %autoreload 3
import os
import sys
from pathlib import Path
import numpy as np
import pandas as pd
from copy import deepcopy
from datetime import datetime, timedelta
from typing import Optional, Dict, List


## Pho's Custom Libraries:
from neuropy.utils.result_context import IdentifyingContext
from neuropy.core.session.Formats.BaseDataSessionFormats import find_local_session_paths
from pyphocorehelpers.Filesystem.path_helpers import find_first_extant_path
from pyphocorehelpers.Filesystem.path_helpers import discover_data_files, generate_copydict, copy_movedict, copy_file, FileList
from pyphocorehelpers.Filesystem.path_helpers import convert_filelist_to_new_parent
from pyphocorehelpers.function_helpers import function_attributes
from pyphocorehelpers.Filesystem.metadata_helpers import FilesystemMetadata, get_file_metadata, get_files_metadata
from pyphoplacecellanalysis.General.Pipeline.Stages.Loading import saveData, loadData
import pyphoplacecellanalysis.General.Batch.runBatch
from pyphoplacecellanalysis.General.Batch.runBatch import BatchRun, BatchResultDataframeAccessor, run_diba_batch, BatchComputationProcessOptions, BatchSessionCompletionHandler, SavingOptions
from pyphoplacecellanalysis.General.Pipeline.NeuropyPipeline import PipelineSavingScheme

from neuropy.core.user_annotations import UserAnnotationsManager
from pyphocorehelpers.Filesystem.metadata_helpers import FilesystemMetadata, get_file_metadata
from pyphocorehelpers.Filesystem.path_helpers import discover_data_files, generate_copydict, copy_movedict, copy_file, save_copydict_to_text_file, read_copydict_from_text_file, invert_filedict
from pyphoplacecellanalysis.General.Batch.runBatch import get_file_str_if_file_exists
from pyphoplacecellanalysis.SpecificResults.AcrossSessionResults import check_output_h5_files, copy_files_in_filelist_to_dest
from pyphoplacecellanalysis.General.Batch.runBatch import ConcreteSessionFolder, BackupMethods

# import glob # for finding .whl file after building binary repo
from pyphoplacecellanalysis.General.Batch.runBatch import BatchRun

known_global_data_root_parent_paths = [Path('/Users/pho/data'), Path(r'/nfs/turbo/umms-kdiba/Data'), Path(r'/media/halechr/MAX/Data'), Path(r'W:/Data'), Path(r'/home/halechr/FastData'), Path(r'/Volumes/MoverNew/data')] # Path(r'/home/halechr/cloud/turbo/Data'), , Path(r'/nfs/turbo/umms-kdiba/Data'), Path(r'/home/halechr/turbo/Data'), 
global_data_root_parent_path = find_first_extant_path(known_global_data_root_parent_paths)
assert global_data_root_parent_path.exists(), f"global_data_root_parent_path: {global_data_root_parent_path} does not exist! Is the right computer's config commented out above?"

# Hardcoded included_session_contexts:
included_session_contexts: List[IdentifyingContext] = UserAnnotationsManager.get_hardcoded_good_sessions()
# included_session_contexts
# excluded_session_keys = ['kdiba_gor01_one_2006-6-08_14-26-15', 'kdiba_gor01_two_2006-6-07_16-40-19', 'kdiba_pin01_one_fet11-01_12-58-54']
# excluded_session_keys = ['2006-6-08_14-26-15', '2006-6-09_1-22-43']
# excluded_session_contexts = [IdentifyingContext.try_init_from_session_key(session_str=v) for v in excluded_session_keys]
# # excluded_session_contexts
excluded_session_contexts = []
included_session_contexts = [v for v in included_session_contexts if v not in excluded_session_contexts]


good_session_concrete_folders = ConcreteSessionFolder.build_concrete_session_folders(global_data_root_parent_path, included_session_contexts)

completed_pipeline_filename = 'loadedSessPickle.pkl'
completed_global_computations_filename = 'global_computation_results.pkl'
# Out:
# [autoreload of pyphoplacecellanalysis.General.Pipeline.Stages.Computation failed: Traceback (most recent call last):
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 274, in check
#     superreload(m, reload, self.old_objects, self.shell)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment only supported for heap types or ModuleType subclasses
# ]
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import ipywidgets as widgets
from ipywidgets import HBox, VBox
from pyphocorehelpers.gui.Jupyter.simple_widgets import build_global_data_root_parent_path_selection_widget
    
all_paths = known_global_data_root_parent_paths
global_data_root_parent_path = global_data_root_parent_path
def on_user_update_path_selection(new_path: Path):
	global global_data_root_parent_path
	new_global_data_root_parent_path = new_path.resolve()
	global_data_root_parent_path = new_global_data_root_parent_path
	print(f'global_data_root_parent_path changed to {global_data_root_parent_path}')
	assert global_data_root_parent_path.exists(), f"global_data_root_parent_path: {global_data_root_parent_path} does not exist! Is the right computer's config commented out above?"
			
global_data_root_parent_path_widget = build_global_data_root_parent_path_selection_widget(all_paths, on_user_update_path_selection)
global_data_root_parent_path_widget
# Out:
# global_data_root_parent_path changed to /nfs/turbo/umms-kdiba/Data
# ToggleButtons(description='Data Root:', layout=Layout(width='auto'), options=(PosixPath('/nfs/turbo/umms-kdiba…

# %%
global_data_root_parent_path
# Out:
# PosixPath('/nfs/turbo/umms-kdiba/Data')

# %%
from neuropy.utils.result_context import IdentifyingContext
from neuropy.core.session.Formats.BaseDataSessionFormats import find_local_session_paths
from pyphocorehelpers.Filesystem.metadata_helpers import FilesystemMetadata, get_file_metadata
from pyphocorehelpers.Filesystem.path_helpers import discover_data_files, generate_copydict, copy_movedict, copy_file, save_copydict_to_text_file, read_copydict_from_text_file, invert_filedict
from pyphoplacecellanalysis.General.Batch.runBatch import get_file_str_if_file_exists
from pyphoplacecellanalysis.SpecificResults.AcrossSessionResults import check_output_h5_files, copy_files_in_filelist_to_dest
from pyphoplacecellanalysis.General.Batch.runBatch import ConcreteSessionFolder, BackupMethods

BATCH_DATE_TO_USE = '2025-01-07_GL' # used for filenames throught the notebook
# BATCH_DATE_TO_USE = '2025-01-07_Lab' # used for filenames throught the notebook
# BATCH_DATE_TO_USE = '2025-01-07_Apogee' # used for filenames throught the notebook
# BATCH_DATE_TO_USE = '2025-01-07_Apogee' # used for filenames throught the notebook

# %% [markdown]
# ## Old (Pre 2023-09-21):

# %%
# Use glob to find the first generated .whl file in the dist/ directory
found_whl_files = glob.glob('*.whl')
found_whl_files = [a for a in found_whl_files if not a.endswith('current.whl')] # exclude the symlink from the search

# %%
external_computed_ripple_filepath = session.basepath.joinpath('ripple_df.pkl')
## try the '.ripple.npy' ripples:
active_file_suffix = '.ripple.npy'
external_computed_ripple_filepath = fp.with_suffix(active_file_suffix)

# %%
## Moves all previously saved loadedSessPickle.pkl files to the output folder.
correctly_placed_output_files = []
search_path: Path = Path("/home/halechr/turbo/Data/KDIBA/").resolve()
assert search_path.exists()
for p in search_path.rglob(completed_pipeline_filename):
    if p.parent.name != 'output':
        # If not already in the 'output/' subfolder, move it there.
        print(f'p: {p}')
        curr_output_dir = p.parent.joinpath('output')
        curr_output_dir.mkdir(exist_ok=True)
        # print(f'curr_output_dir: {curr_output_dir}')
        new_path = p.replace(curr_output_dir.joinpath(p.name))
        print(f'\t new_path: {new_path}')
        correctly_placed_output_files.append(p)
    else:
        print(f'p: {p} already in output folder.')
        correctly_placed_output_files.append(p)
    
correctly_placed_output_files

# %%
completed_pipeline_filename

# %%
## Build Pickle Path:
pkl_path = 'global_batch_result_2023-06-08.pkl'
csv_path = 'global_batch_result_2023-06-08.csv'
h5_path = 'global_batch_result_2023-06-08.h5'

global_batch_result_file_path = Path(global_data_root_parent_path).joinpath(h5_path).resolve() # Use Default

batch_progress_df = BatchRun.load_batch_progress_df_from_h5(global_batch_result_file_path)
batch_progress_df

updated_batch_progress_df = BatchRun.rebuild_basedirs(batch_progress_df, global_data_root_parent_path)
updated_batch_progress_df

updated_good_only_batch_progress_df = updated_batch_progress_df[updated_batch_progress_df['locally_is_ready']].copy()
updated_good_only_batch_progress_df

# %%
# Generate code that can be pasted into the current "ReviewOfWork-*.ipynb" notebook to load the good sessions:
print(",\n".join([a_ctxt.get_initialization_code_string() for a_ctxt in updated_good_only_batch_progress_df['context'].to_list()]))

# %% [markdown]
# # 2023-09-21 - Mirror Slow Data files to much faster SSD: , Path(r'/home/halechr/FastData')

# %%
import os
from pathlib import Path
import shutil # used in `restore_symlink_folder`
from shutil import copytree # used in `make_specific_items_local`
from typing import Optional, Dict, List
from datetime import datetime, timedelta
from pyphocorehelpers.Filesystem.metadata_helpers import FilesystemMetadata, get_file_metadata
from pyphocorehelpers.Filesystem.path_helpers import discover_data_files, generate_copydict, copy_movedict, copy_file
from attrs import define, field, Factory

# %%
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01') ## DO NOT CALL .resolve() on the input path, this resolves the symlink!!!
print(f'existing_symlink_folder_path: {a_symlink_path}')
assert a_symlink_path.exists()
symlinked_folder_to_local_folder_containing_symlinks(a_symlink_path, dryrun=False)

# %%
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01/one') ## DO NOT CALL .resolve() on the input path, this resolves the symlink!!!
print(f'existing_symlink_folder_path: {a_symlink_path}')
assert a_symlink_path.exists()
symlinked_folder_to_local_folder_containing_symlinks(a_symlink_path, dryrun=False)

# %%
# make_specific_items_local

# existing_symlink_folder_path: Path = Path('/home/halechr/FastData/KDIBA/pin01') ## DO NOT CALL .resolve() on the input path, this resolves the symlink!!!
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01/one')
print(f'existing_symlink_folder_path: {a_symlink_path}')
assert a_symlink_path.exists()
desired_local_folder_paths: List[Path] = [Path(v) for v in ['/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/output/global_computation_results.pkl', '/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/loadedSessPickle.pkl',
                                                            '/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/output/global_computation_results.pkl', '/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/loadedSessPickle.pkl',
                                                            '/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/output/global_computation_results.pkl', '/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/loadedSessPickle.pkl',
                                                            ]]
make_specific_items_local(a_symlink_path, desired_local_folder_paths=desired_local_folder_paths, dryrun=True)

# %%
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01/one/fet11-01_12-58-54') ## DO NOT CALL .resolve() on the input path, this resolves the symlink!!!
print(f'existing_symlink_path: {a_symlink_path}')
assert a_symlink_path.exists()
symlinked_item_to_full_local_item(a_symlink_path, dryrun=True)

# %%
# existing_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01/one/11-09_22-4-5/11-09_22-4-5IN.5.numclu')
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/output/global_computation_results.pkl')
print(f'existing_symlink_path: {a_symlink_path}')
assert a_symlink_path.exists()
symlinked_item_to_full_local_item(a_symlink_path, dryrun=False)

# %%
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/vvp01/one/2006-4-18_13-6-1/loadedSessPickle.pkl')
print(f'existing_symlink_path: {a_symlink_path}')
assert a_symlink_path.exists()
symlinked_item_to_full_local_item(a_symlink_path, dryrun=False)

# %%
a_symlink_path: Path = Path('/home/halechr/FastData/KDIBA/pin01') ## DO NOT CALL .resolve() on the input path, this resolves the symlink!!!
print(f'existing_symlink_folder_path: {a_symlink_path}')
assert a_symlink_path.exists()
restore_symlink_folder(a_symlink_path, dryrun=False)

# %%
def attribute_is_extant_path(instance, attribute, value):
	if not isinstance(value, Path):
		raise TypeError(f"value must be a pathlib.Path but type(value): {type(value)}")
	if not value.exists():
		raise ValueError(f"value must exists on the filesystem!")
	


@define(slots=False)
class DataRepository:
	short_name: str = field()
	host: str = field()
	root_path: Path = field()

	# def __attrs_post_init__(self):
	# 	assert root_path.exists()
		
		
	def try_find_files(self):
		# Find the files and build the movedicts:
		source_data_root = self.root_path.resolve()
		found_session_pickle_files = discover_data_files(source_data_root, glob_pattern='loadedSessPickle.pkl', recursive=True)
		found_global_computation_results_files = discover_data_files(source_data_root, glob_pattern=f'output/{completed_global_computations_filename}', recursive=True)
		return found_session_pickle_files, found_global_computation_results_files

data_repos = {'MAX':DataRepository('MAX', host='LNX00052', root_path=Path(r'/media/MAX/Data')),
'FastData':DataRepository('FastData', host='LNX00052', root_path=Path(r'/home/halechr/FastData')),
'gen_scripts':DataRepository('gen_scripts', host='LNX00052', root_path=Path(r'/home/halechr/FastData/gen_scripts/')),
}


included_session_contexts = [
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-08_14-26-15'), # prev completed
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-09_1-22-43'), # prev completed
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-12_15-55-31'), # prev completed
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-07_16-40-19'), # prev completed
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-08_21-16-25'),
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-09_22-24-40'),
    # IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-12_16-53-46'),
    # IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='one',session_name='2006-4-09_17-29-30'),
    # IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='one',session_name='2006-4-10_12-25-50'),
    # IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='two',session_name='2006-4-09_16-40-54'),
    # IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='two',session_name='2006-4-10_12-58-3'),
    # IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-02_17-46-44'), # prev completed
    # IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-02_19-28-0'),
    # IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-03_12-3-25'),
	  IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-09_22-4-5'),
    # IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='fet11-01_12-58-54'), # prev completed
]

data_repos_good_session_concrete_folders_dict = {}

data_repos
# run_kdiba_gor01_one_2006-6-08_14-26-15

# %%
curr_good_session_concrete_folders = ConcreteSessionFolder.build_concrete_session_folders(data_repos['MAX'].root_path.resolve(), included_session_contexts)
curr_good_session_concrete_folders

# %%
included_session_contexts

# %%
data_repos_good_session_concrete_folders_dict['FastData'] = ConcreteSessionFolder.build_concrete_session_folders(data_repos['FastData'].root_path.resolve(), included_session_contexts, allow_create_needed_dirs=True)
data_repos_good_session_concrete_folders_dict['FastData']

# %%
good_session_concrete_folders

# %%
# copy_dict = ConcreteSessionFolder.build_backup_copydict(data_repos_good_session_concrete_folders_dict['FastData'], backup_mode=BackupMethods.RenameInSourceDirectory, rename_backup_suffix=BATCH_DATE_TO_USE, only_include_file_types=['global_pkl'])
copy_dict_FastData = ConcreteSessionFolder.build_backup_copydict(data_repos_good_session_concrete_folders_dict['FastData'], backup_mode=BackupMethods.RenameInSourceDirectory, rename_backup_suffix=BATCH_DATE_TO_USE, only_include_file_types=['local_pkl', 'global_pkl'])
copy_dict_FastData

# %%
moved_files_dict_FastData_files = copy_movedict(copy_dict_FastData)
moved_files_dict_FastData_files

# %%
found_session_pickle_files, found_global_computation_results_files = data_repos['MAX'].try_find_files()
found_session_pickle_files

# %%
source_data_root = Path(r'/media/MAX/Data')
dest_data_root = Path(r'/home/halechr/FastData')
assert source_data_root.exists(), f"source_data_root: {source_data_root} does not exist! Is the right computer's config commented out above?"
assert dest_data_root.exists(), f"dest_data_root: {dest_data_root} does not exist! Is the right computer's config commented out above?"

oldest_modified_date = (datetime.now() - timedelta(days=5))

# %%
# Find the files and build the movedicts:
found_session_pickle_files = discover_data_files(source_data_root, glob_pattern='loadedSessPickle.pkl', recursive=True)
found_global_computation_results_files = discover_data_files(source_data_root, glob_pattern=f'output/{completed_global_computations_filename}', recursive=True)
file_movedict_session_pickle_files = generate_copydict(source_data_root, dest_data_root, found_files=found_session_pickle_files, only_files_newer_than=oldest_modified_date)
file_movedict_global_computation_results_pickle_files = generate_copydict(source_data_root, dest_data_root, found_files=found_global_computation_results_files, only_files_newer_than=oldest_modified_date)

# %% [markdown]
# ### Actually perform copy operations. This will take a while

# %%
moved_files_dict_session_pickle_files = copy_movedict(file_movedict_session_pickle_files)
moved_files_dict_session_pickle_files

# moved_files_dict = copy_files(filelist_source, filelist_dest)

# %%
moved_files_dict_global_computation_results_pickle_files = copy_movedict(file_movedict_global_computation_results_pickle_files)
moved_files_dict_global_computation_results_pickle_files

# %% [markdown]
# # Various file formats:
# 'global_computation_results_2023-12-07_GL.pkl'
# '20231012125859-global_computation_results.pkltmp'
# "loadedSessPickle_2023-12-07_GL.pkl"
# "backup-20231020190542-loadedSessPickle.pkl"
# "loadedSessPickle_2023-10-25_BidirectionalOnly"
# "20230912203733-loadedSessPickle.pkl"
# "backup-20240125143331-loadedSessPickle.pkl.bak"
# "20231129083822-loadedSessPickle.pkl"

# %%
from pyphocorehelpers.Filesystem.path_helpers import parse_unique_file_name
import re
from datetime import datetime

def detect_date_strings(filenames):
    # Regular expression pattern for date (YYYY-MM-DD)
    date_pattern = r'\d{4}-\d{2}-\d{2}'
    # Regular expression pattern for datetime (YYYYMMDDHHMMSS)
    datetime_pattern = r'\d{14}'

    detected_dates = []

    for filename in filenames:
        date_match = re.search(date_pattern, filename)
        datetime_match = re.search(datetime_pattern, filename)

        if date_match:
            date_str = date_match.group()
            # Parse the date string
            try:
                date_value = datetime.strptime(date_str, '%Y-%m-%d')
            except ValueError as e:
                print(f"Error parsing date: {e}")
                date_value = None
            detected_dates.append((date_str, date_value))
        elif datetime_match:
            datetime_str = datetime_match.group()
            # Parse the datetime string
            try:
                datetime_value = datetime.strptime(datetime_str, '%Y%m%d%H%M%S')
            except ValueError as e:
                print(f"Error parsing datetime: {e}")
                datetime_value = None
            detected_dates.append((datetime_str, datetime_value))
        else:
            detected_dates.append((None, None))  # No date/datetime found

    return detected_dates


test_filenames = ['global_computation_results_2023-12-07_GL.pkl',
'20231012125859-global_computation_results.pkltmp',
"loadedSessPickle_2023-12-07_GL.pkl",
"backup-20231020190542-loadedSessPickle.pkl",
"loadedSessPickle_2023-10-25_BidirectionalOnly",
"20230912203733-loadedSessPickle.pkl",
"backup-20240125143331-loadedSessPickle.pkl.bak",
"20231129083822-loadedSessPickle.pkl"]

# [parse_unique_file_name(a_filename) for a_filename in test_filenames]

detected_dates = detect_date_strings(test_filenames)
for filename, (date_str, date_value) in zip(test_filenames, detected_dates):
    print(f'{filename} --> {date_str}, {date_value}')

# %%
from neuropy.core.session.Formats.SessionSpecifications import SessionFolderSpec, SessionFileSpec


def get_pipeline_output_files(session_name: str):

    return SessionFolderSpec(optional=[SessionFileSpec('loadedSessPickle.pkl', session_name, 'The entire computed pipeline', None),
            SessionFileSpec('{}.mua.npy', session_name, 'Multi-Unit Acitivity Cache', None),
            SessionFileSpec('{}.pbe.npy', session_name, 'Population Burst Events Cache', None),
            SessionFileSpec('{}.interpolated_spike_positions.npy', session_name, 'Position-interpolated spike info computed from the spike times and the positions', None),
            SessionFileSpec('{}.position.npy', session_name, 'Interpolated position info with additional properties', None),
            # SessionFolderSpec(optional=[SessionFileSpec(global_computation_results.pkl', session_name, 'The global (across-epoch) computation functions computed results for the pipeline', None),
                # ]
            # ),
            SessionFileSpec('output/global_computation_results.pkl', session_name, 'The global (across-epoch) computation functions computed results for the pipeline', None),
        ]
    )
# Out:
# [autoreload of pyphoplacecellanalysis.General.Pipeline.Stages.Computation failed: Traceback (most recent call last):
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 274, in check
#     superreload(m, reload, self.old_objects, self.shell)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 500, in superreload
#     update_generic(old_obj, new_obj)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 397, in update_generic
#     update(a, b)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 365, in update_class
#     update_instances(old, new)
#   File "/home/halechr/repos/Spike3D/.venv/lib/python3.9/site-packages/IPython/extensions/autoreload.py", line 323, in update_instances
#     object.__setattr__(ref, "__class__", new)
# TypeError: __class__ assignment only supported for heap types or ModuleType subclasses
# ]

# %%
# Hardcoded included_session_contexts:
from typing import Tuple

included_session_contexts = [
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-08_14-26-15'), # prev completed
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-09_1-22-43'), # prev completed
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='one',session_name='2006-6-12_15-55-31'), # prev completed
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-07_16-40-19'), # prev completed
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-08_21-16-25'),
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-09_22-24-40'),
    IdentifyingContext(format_name='kdiba',animal='gor01',exper_name='two',session_name='2006-6-12_16-53-46'),
    IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='one',session_name='2006-4-09_17-29-30'),
    IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='one',session_name='2006-4-10_12-25-50'),
    IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='two',session_name='2006-4-09_16-40-54'),
    IdentifyingContext(format_name='kdiba',animal='vvp01',exper_name='two',session_name='2006-4-10_12-58-3'),
    IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-02_17-46-44'), # prev completed
    IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-02_19-28-0'),
    IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='11-03_12-3-25'),
    IdentifyingContext(format_name='kdiba',animal='pin01',exper_name='one',session_name='fet11-01_12-58-54'), # prev completed
]

# ...
# (WindowsPath('W:/Data/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle.pkl'),
#     {'path': 'W:\\Data\\KDIBA\\vvp01\\one\\2006-4-10_12-25-50\\loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 12, 16, 19, 43, 45, 291007),
#      'creation_time': datetime.datetime(2023, 6, 6, 23, 16, 16, 393205),
#      'file_size': 4.68}),
# ...

active_global_batch_result_filename=f'global_batch_result_{BATCH_DATE_TO_USE}.pkl'

debug_print = False
known_global_data_root_parent_paths = [Path(r'/home/halechr/cloud/turbo/Data'), Path(r'W:\Data'), Path(r'/nfs/turbo/umms-kdiba/Data'), Path(r'/media/MAX/Data'), Path(r'/Volumes/MoverNew/data')] # , Path(r'/home/halechr/FastData'), Path(r'/nfs/turbo/umms-kdiba/Data'), Path(r'/home/halechr/turbo/Data'), 
global_data_root_parent_path = find_first_extant_path(known_global_data_root_parent_paths)
assert global_data_root_parent_path.exists(), f"global_data_root_parent_path: {global_data_root_parent_path} does not exist! Is the right computer's config commented out above?"
good_session_concrete_folders = ConcreteSessionFolder.build_concrete_session_folders(global_data_root_parent_path, included_session_contexts)

## Build session paths dictionary:
session_basedirs_dict: Dict[IdentifyingContext, Path] = {a_session_folder.context:a_session_folder.path for a_session_folder in good_session_concrete_folders}
# found_files_dict: Dict[IdentifyingContext, Tuple[List[Path], List[Path]]] = {}

found_files_dict: Dict[IdentifyingContext, Tuple[List[Tuple[Path, Dict]], List[Tuple[Path, Dict]]]] = {}


for a_ctxt, a_path in session_basedirs_dict.items():
    found_any_kind_session_pickle_files = discover_data_files(a_path, glob_pattern='*loadedSessPickle*.pkl', recursive=True)
    found_any_global_computation_results_files = discover_data_files(a_path, glob_pattern='output/*global_computation_results*.pkl', recursive=True)
    # metadata_dict = {'found_any_kind_session_pickle_files': get_files_metadata(found_any_kind_session_pickle_files),
    #                     'found_any_global_computation_results_files': get_files_metadata(found_any_kind_session_pickle_files)
    # }
    found_any_kind_session_pickle_files = [(f, get_file_metadata(f)) for f in found_any_kind_session_pickle_files]
    found_any_global_computation_results_files = [(f, get_file_metadata(f)) for f in found_any_global_computation_results_files]

    # found_files_dict[a_ctxt] = (found_any_kind_session_pickle_files, found_any_global_computation_results_files)
    found_files_dict[a_ctxt] = (found_any_kind_session_pickle_files, found_any_global_computation_results_files)

found_files_dict
# Out:
# {Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-08_14-26-15'): ([(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241105150345-loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241105150345-loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 15, 3, 55, 2651),
#      'creation_time': datetime.datetime(2024, 11, 5, 15, 3, 55, 2651),
#      'file_size': 0.26}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241107182055-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241107182055-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 7, 18, 21, 24, 140529),
#      'creation_time': datetime.datetime(2024, 11, 7, 18, 21, 24, 140529),
#      'file_size': 2.45}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241108125129-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241108125129-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 8, 12, 51, 46, 352118),
#      'creation_time': datetime.datetime(2024, 11, 8, 12, 51, 46, 352118),
#      'file_size': 2.37}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 15, 24, 19, 960569),
#      'creation_time': datetime.datetime(2024, 10, 30, 15, 24, 20, 441712),
#      'file_size': 4.71}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 27, 30, 909856),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 27, 36, 981672),
#      'file_size': 4.71}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 15, 13, 776555),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 15, 14, 183432),
#      'file_size': 4.71}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 11, 58, 467908),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 11, 58, 509882),
#      'file_size': 16.02}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 7, 59, 216122),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 8, 0, 517422),
#      'file_size': 16.02}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 47, 46, 427143),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 47, 46, 887213),
#      'file_size': 15.43}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 3, 3, 872293),
#      'creation_time': datetime.datetime(2024, 11, 4, 19, 51, 42, 685358),
#      'file_size': 4.71}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 19, 48, 2, 310332),
#      'creation_time': datetime.datetime(2024, 11, 6, 19, 49, 21, 824008),
#      'file_size': 16.13}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 4, 16, 51, 14, 158075),
#      'creation_time': datetime.datetime(2024, 7, 4, 16, 51, 14, 158075),
#      'file_size': 8.03}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 4, 16, 36, 55, 290696),
#      'creation_time': datetime.datetime(2024, 7, 4, 16, 36, 55, 290696),
#      'file_size': 10.47}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 2, 18, 27, 583778),
#      'creation_time': datetime.datetime(2024, 7, 9, 2, 18, 28, 16097),
#      'file_size': 10.47})],
#   [(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results.pkl',
#      'modification_time': datetime.datetime(2024, 10, 29, 14, 57, 36, 608236),
#      'creation_time': datetime.datetime(2024, 10, 29, 14, 57, 37, 24616),
#      'file_size': 5.36}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 40, 7, 36425),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 40, 7, 310247),
#      'file_size': 5.33}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 30, 28, 778051),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 30, 33, 285653),
#      'file_size': 5.33}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 16, 2, 972826),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 16, 3, 532131),
#      'file_size': 5.33}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 44, 12, 410032),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 44, 12, 495229),
#      'file_size': 5.09}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 19, 27, 7, 120468),
#      'creation_time': datetime.datetime(2024, 10, 21, 19, 27, 7, 746065),
#      'file_size': 5.33}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 28, 16, 48, 47, 259929),
#      'creation_time': datetime.datetime(2024, 11, 28, 16, 48, 47, 875979),
#      'file_size': 5.12}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 8, 28, 587583),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 8, 29, 406257),
#      'file_size': 5.12}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 48, 54, 20496),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 48, 54, 32861),
#      'file_size': 5.01}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 3, 39, 40270),
#      'creation_time': datetime.datetime(2024, 10, 30, 17, 3, 39, 409840),
#      'file_size': 4.81})]),
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-09_1-22-43'): ([(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240710135946-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240710135946-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 10, 14, 1, 6, 61564),
#      'creation_time': datetime.datetime(2024, 7, 10, 14, 1, 6, 61564),
#      'file_size': 10.38}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240715204503-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240715204503-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 15, 20, 46, 24, 492540),
#      'creation_time': datetime.datetime(2024, 7, 15, 20, 46, 24, 492540),
#      'file_size': 10.37}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240716052924-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240716052924-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 5, 31, 13, 333124),
#      'creation_time': datetime.datetime(2024, 7, 16, 5, 31, 13, 333124),
#      'file_size': 10.37}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240717011236-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240717011236-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 17, 1, 13, 44, 671712),
#      'creation_time': datetime.datetime(2024, 7, 17, 1, 13, 44, 671712),
#      'file_size': 9.75}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828173432-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828173432-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 8, 28, 17, 35, 39, 798911),
#      'creation_time': datetime.datetime(2024, 8, 28, 17, 35, 39, 798911),
#      'file_size': 9.02}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828225831-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828225831-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 8, 28, 22, 59, 38, 184951),
#      'creation_time': datetime.datetime(2024, 8, 28, 22, 59, 38, 184951),
#      'file_size': 10.3}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829030301-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829030301-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 8, 29, 3, 4, 13, 513057),
#      'creation_time': datetime.datetime(2024, 8, 29, 3, 4, 13, 513057),
#      'file_size': 10.29}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829064622-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829064622-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 8, 29, 6, 47, 34, 842154),
#      'creation_time': datetime.datetime(2024, 8, 29, 6, 47, 34, 842154),
#      'file_size': 10.3}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829091715-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829091715-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 8, 29, 9, 18, 27, 182228),
#      'creation_time': datetime.datetime(2024, 8, 29, 9, 18, 27, 182228),
#      'file_size': 10.3}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241107181515-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241107181515-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 7, 18, 16, 9, 763208),
#      'creation_time': datetime.datetime(2024, 11, 7, 18, 16, 9, 763208),
#      'file_size': 6.27}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241108124734-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241108124734-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 8, 12, 48, 16, 36583),
#      'creation_time': datetime.datetime(2024, 11, 8, 12, 48, 16, 36583),
#      'file_size': 6.26}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 10, 31, 12, 19, 8, 95173),
#      'creation_time': datetime.datetime(2024, 10, 31, 12, 19, 8, 484845),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 44, 2, 865699),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 44, 4, 249070),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 31, 9, 924067),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 31, 11, 12479),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 16, 39, 646303),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 16, 40, 237609),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 45, 42, 40810),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 45, 42, 396175),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 2, 21, 1, 140898),
#      'creation_time': datetime.datetime(2024, 7, 9, 2, 21, 1, 312950),
#      'file_size': 9.63}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 2, 27, 19, 348950),
#      'creation_time': datetime.datetime(2024, 7, 9, 2, 27, 19, 697736),
#      'file_size': 9.61}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 33, 48, 867501),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 33, 49, 292556),
#      'file_size': 14.28}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 30, 16, 943614),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 30, 18, 396223),
#      'file_size': 10.07}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 45, 0, 668012),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 45, 0, 916805),
#      'file_size': 13.74}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 46, 410730),
#      'creation_time': datetime.datetime(2024, 11, 4, 16, 28, 11, 794032),
#      'file_size': 4.23}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 19, 34, 19, 81045),
#      'creation_time': datetime.datetime(2024, 11, 6, 19, 34, 19, 759324),
#      'file_size': 14.4}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 21, 9, 4, 13, 81165),
#      'creation_time': datetime.datetime(2024, 11, 21, 9, 4, 13, 81165),
#      'file_size': 14.31}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 2, 10, 5, 80059),
#      'creation_time': datetime.datetime(2024, 7, 9, 2, 10, 5, 275493),
#      'file_size': 9.64}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 1, 58, 43, 22439),
#      'creation_time': datetime.datetime(2024, 7, 9, 1, 58, 43, 142702),
#      'file_size': 9.62})],
#   [(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results.pkl',
#      'modification_time': datetime.datetime(2024, 10, 29, 13, 7, 7, 909470),
#      'creation_time': datetime.datetime(2024, 10, 29, 13, 7, 8, 304293),
#      'file_size': 5.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 44, 27, 135480),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 44, 27, 431148),
#      'file_size': 5.13}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 31, 38, 685739),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 31, 38, 913203),
#      'file_size': 5.13}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 17, 14, 508807),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 17, 15, 109319),
#      'file_size': 5.13}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 45, 58, 658316),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 45, 59, 22716),
#      'file_size': 4.91}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 19, 14, 18, 940791),
#      'creation_time': datetime.datetime(2024, 10, 21, 19, 14, 19, 731288),
#      'file_size': 5.13}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 28, 16, 48, 9, 698420),
#      'creation_time': datetime.datetime(2024, 11, 28, 16, 48, 10, 221192),
#      'file_size': 4.92}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 7, 30, 43, 516305),
#      'creation_time': datetime.datetime(2024, 11, 6, 7, 30, 44, 240646),
#      'file_size': 4.92}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 45, 58, 151071),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 45, 58, 580547),
#      'file_size': 4.85}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 3, 13, 658476),
#      'creation_time': datetime.datetime(2024, 10, 30, 17, 3, 14, 126009),
#      'file_size': 4.68})]),
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-12_15-55-31'): ([(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 15, 19, 25, 589348),
#      'creation_time': datetime.datetime(2024, 10, 30, 15, 19, 26, 18744),
#      'file_size': 2.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 45, 3, 750491),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 45, 6, 131606),
#      'file_size': 2.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 31, 51, 650639),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 31, 51, 981803),
#      'file_size': 2.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 17, 46, 490673),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 17, 47, 72120),
#      'file_size': 2.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 22, 18, 56, 861118),
#      'creation_time': datetime.datetime(2024, 7, 16, 22, 18, 57, 288179),
#      'file_size': 2.93}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 22, 22, 9, 816425),
#      'creation_time': datetime.datetime(2024, 7, 16, 22, 22, 10, 227860),
#      'file_size': 2.88}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 5, 10, 5, 250216),
#      'creation_time': datetime.datetime(2024, 11, 6, 5, 10, 5, 256052),
#      'file_size': 5.41}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 5, 8, 20, 56765),
#      'creation_time': datetime.datetime(2024, 11, 6, 5, 8, 21, 409498),
#      'file_size': 4.02}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 19, 53, 489841),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 19, 54, 54618),
#      'file_size': 5.18}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 13, 389426),
#      'creation_time': datetime.datetime(2024, 11, 4, 16, 28, 12, 51529),
#      'file_size': 2.15}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 19, 10, 17, 16, 539622),
#      'creation_time': datetime.datetime(2024, 11, 19, 10, 17, 20, 739651),
#      'file_size': 5.49}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 27, 23, 15, 41, 317870),
#      'creation_time': datetime.datetime(2024, 11, 27, 23, 15, 42, 388816),
#      'file_size': 5.52}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 22, 8, 28, 215943),
#      'creation_time': datetime.datetime(2024, 7, 16, 22, 8, 28, 618374),
#      'file_size': 2.88}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 4, 16, 25, 4, 14653),
#      'creation_time': datetime.datetime(2024, 7, 4, 16, 25, 4, 14653),
#      'file_size': 3.61}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 22, 4, 5, 173848),
#      'creation_time': datetime.datetime(2024, 7, 16, 22, 4, 5, 588610),
#      'file_size': 2.88}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/outputs/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/outputs/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2023, 5, 20, 0, 41, 44, 236990),
#      'creation_time': datetime.datetime(2023, 5, 23, 18, 48, 14, 854440),
#      'file_size': 0.3})],
#   [(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results.pkl',
#      'modification_time': datetime.datetime(2024, 10, 29, 12, 20, 44, 113414),
#      'creation_time': datetime.datetime(2024, 10, 29, 12, 20, 45, 385619),
#      'file_size': 1.39}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 45, 16, 176361),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 45, 16, 239314),
#      'file_size': 0.07}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 31, 53, 162726),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 31, 53, 503862),
#      'file_size': 0.07}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 17, 57, 740599),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 17, 58, 313049),
#      'file_size': 1.38}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 44, 15, 451314),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 44, 16, 387475),
#      'file_size': 1.46}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 18, 19, 4, 526809),
#      'creation_time': datetime.datetime(2024, 10, 21, 18, 19, 6, 79418),
#      'file_size': 1.38}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 28, 16, 46, 24, 32446),
#      'creation_time': datetime.datetime(2024, 11, 28, 16, 46, 24, 919148),
#      'file_size': 1.48}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 5, 8, 35, 368616),
#      'creation_time': datetime.datetime(2024, 11, 6, 5, 8, 36, 347898),
#      'file_size': 1.48}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 20, 9, 656267),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 20, 10, 357279),
#      'file_size': 1.44}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 30, 149184),
#      'creation_time': datetime.datetime(2024, 10, 30, 17, 2, 31, 352343),
#      'file_size': 1.37})]),
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'two', session_name= '2006-6-07_16-40-19'): ([(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240705193651-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240705193651-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 5, 19, 37, 48, 908289),
#      'creation_time': datetime.datetime(2024, 7, 5, 19, 37, 48, 908289),
#      'file_size': 8.0}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240706014544-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240706014544-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 6, 1, 46, 53, 157075),
#      'creation_time': datetime.datetime(2024, 7, 6, 1, 46, 53, 157075),
#      'file_size': 8.55}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240708152121-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240708152121-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 8, 15, 22, 29, 731195),
#      'creation_time': datetime.datetime(2024, 7, 8, 15, 22, 29, 731195),
#      'file_size': 8.55}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709011930-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709011930-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 1, 20, 40, 440717),
#      'creation_time': datetime.datetime(2024, 7, 9, 1, 20, 40, 440717),
#      'file_size': 8.55}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709025951-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709025951-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 3, 1, 18, 14962),
#      'creation_time': datetime.datetime(2024, 7, 9, 3, 1, 18, 14962),
#      'file_size': 8.53}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240710135952-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240710135952-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 10, 14, 1, 2, 20998),
#      'creation_time': datetime.datetime(2024, 7, 10, 14, 1, 2, 20998),
#      'file_size': 10.0}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240715205330-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240715205330-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 15, 20, 55, 10, 461267),
#      'creation_time': datetime.datetime(2024, 7, 15, 20, 55, 10, 461267),
#      'file_size': 9.99}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240716053230-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240716053230-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 5, 34, 29, 69268),
#      'creation_time': datetime.datetime(2024, 7, 16, 5, 34, 29, 69268),
#      'file_size': 10.0}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241107182153-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241107182153-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 7, 18, 22, 45, 282031),
#      'creation_time': datetime.datetime(2024, 11, 7, 18, 22, 45, 282031),
#      'file_size': 5.85}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241108125422-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241108125422-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 8, 12, 55, 8, 929486),
#      'creation_time': datetime.datetime(2024, 11, 8, 12, 55, 8, 929486),
#      'file_size': 5.85}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 15, 23, 29, 472369),
#      'creation_time': datetime.datetime(2024, 10, 30, 15, 23, 30, 72256),
#      'file_size': 5.5}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 46, 3, 322060),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 46, 3, 627162),
#      'file_size': 5.5}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 37, 49, 971790),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 37, 50, 266485),
#      'file_size': 5.5}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 18, 56, 519169),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 18, 56, 703777),
#      'file_size': 5.5}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 19, 36, 56, 131807),
#      'creation_time': datetime.datetime(2024, 10, 21, 19, 36, 56, 552484),
#      'file_size': 5.5}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
# ...
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 19, 9, 20, 42, 754134),
#      'creation_time': datetime.datetime(2024, 11, 19, 9, 20, 44, 122072),
#      'file_size': 3.66}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 27, 21, 14, 58, 545284),
#      'creation_time': datetime.datetime(2024, 11, 27, 21, 14, 58, 835921),
#      'file_size': 3.68}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/outputs/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/outputs/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2023, 5, 20, 0, 57, 44, 476705),
#      'creation_time': datetime.datetime(2023, 5, 23, 18, 48, 14, 658411),
#      'file_size': 0.16})],
#   [(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results.pkl',
#      'modification_time': datetime.datetime(2024, 10, 29, 11, 56, 59, 393110),
#      'creation_time': datetime.datetime(2024, 10, 29, 11, 57, 0, 212394),
#      'file_size': 0.82}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 57, 37, 504069),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 57, 37, 856031),
#      'file_size': 0.03}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 57, 18, 546399),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 57, 18, 769623),
#      'file_size': 0.03}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 23, 24, 492991),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 23, 25, 843084),
#      'file_size': 0.82}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 43, 48, 852409),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 43, 49, 398016),
#      'file_size': 0.8}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 18, 0, 59, 203831),
#      'creation_time': datetime.datetime(2024, 10, 21, 18, 1, 0, 986789),
#      'file_size': 0.82}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 28, 16, 46, 12, 756570),
#      'creation_time': datetime.datetime(2024, 11, 28, 16, 46, 13, 871898),
#      'file_size': 0.86}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 3, 44, 29, 885680),
#      'creation_time': datetime.datetime(2024, 11, 6, 3, 44, 31, 587187),
#      'file_size': 0.86}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 11, 22, 108137),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 11, 23, 306081),
#      'file_size': 0.84}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 4, 456486),
#      'creation_time': datetime.datetime(2024, 10, 30, 17, 2, 5, 307925),
#      'file_size': 0.81})]),
#  Context(format_name= 'kdiba', animal= 'pin01', exper_name= 'one', session_name= 'fet11-01_12-58-54'): ([(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 15, 20, 27, 816370),
#      'creation_time': datetime.datetime(2024, 10, 30, 15, 20, 28, 145268),
#      'file_size': 4.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 58, 8, 779736),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 58, 8, 907463),
#      'file_size': 4.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 59, 18, 567919),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 59, 19, 301274),
#      'file_size': 4.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 24, 17, 109669),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 24, 17, 937923),
#      'file_size': 4.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 8, 16, 28, 582818),
#      'creation_time': datetime.datetime(2024, 11, 6, 8, 16, 29, 958202),
#      'file_size': 10.57}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 8, 13, 52, 877112),
#      'creation_time': datetime.datetime(2024, 11, 6, 8, 13, 53, 448675),
#      'file_size': 10.57}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 35, 31, 675474),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 35, 32, 303051),
#      'file_size': 10.09}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 36, 888151),
#      'creation_time': datetime.datetime(2024, 11, 4, 19, 51, 42, 756879),
#      'file_size': 4.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 8, 12, 53, 8, 323931),
#      'creation_time': datetime.datetime(2024, 11, 8, 12, 53, 8, 826389),
#      'file_size': 10.51}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl',
#      'modification_time': datetime.datetime(2024, 11, 21, 12, 9, 45, 537763),
#      'creation_time': datetime.datetime(2024, 11, 21, 12, 9, 45, 537763),
#      'file_size': 10.63}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl',
#      'modification_time': datetime.datetime(2024, 7, 16, 5, 22, 22, 560873),
#      'creation_time': datetime.datetime(2024, 7, 16, 5, 22, 22, 673260),
#      'file_size': 10.19}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/outputs/loadedSessPickle.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/outputs/loadedSessPickle.pkl',
#      'modification_time': datetime.datetime(2023, 5, 20, 0, 58, 44, 234032),
#      'creation_time': datetime.datetime(2023, 5, 23, 18, 48, 14, 684723),
#      'file_size': 0.32})],
#   [(PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results.pkl',
#      'modification_time': datetime.datetime(2024, 10, 29, 14, 8, 58, 352428),
#      'creation_time': datetime.datetime(2024, 10, 29, 14, 8, 59, 475827),
#      'file_size': 2.61}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-11_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-11_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 11, 21, 58, 55, 287095),
#      'creation_time': datetime.datetime(2024, 9, 11, 21, 58, 55, 830809),
#      'file_size': 2.58}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-26_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-26_GL.pkl',
#      'modification_time': datetime.datetime(2024, 9, 27, 3, 59, 59, 214243),
#      'creation_time': datetime.datetime(2024, 9, 27, 3, 59, 59, 420786),
#      'file_size': 2.58}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-10-23_GL.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-10-23_GL.pkl',
#      'modification_time': datetime.datetime(2024, 10, 23, 15, 24, 33, 939549),
#      'creation_time': datetime.datetime(2024, 10, 23, 15, 24, 34, 225474),
#      'file_size': 2.58}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-09.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-09.pkl',
#      'modification_time': datetime.datetime(2024, 7, 9, 6, 45, 52, 674550),
#      'creation_time': datetime.datetime(2024, 7, 9, 6, 45, 52, 966392),
#      'file_size': 2.64}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 21, 19, 23, 42, 394517),
#      'creation_time': datetime.datetime(2024, 10, 21, 19, 23, 43, 718276),
#      'file_size': 2.58}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl',
#      'modification_time': datetime.datetime(2024, 11, 28, 16, 49, 10, 601154),
#      'creation_time': datetime.datetime(2024, 11, 28, 16, 49, 11, 8341),
#      'file_size': 2.73}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 11, 6, 8, 14, 13, 845813),
#      'creation_time': datetime.datetime(2024, 11, 6, 8, 14, 14, 731939),
#      'file_size': 2.73}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl',
#      'modification_time': datetime.datetime(2024, 11, 5, 8, 36, 9, 368982),
#      'creation_time': datetime.datetime(2024, 11, 5, 8, 36, 9, 860825),
#      'file_size': 2.6}),
#    (PosixPath('/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'),
#     {'path': '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl',
#      'modification_time': datetime.datetime(2024, 10, 30, 17, 2, 56, 78004),
#      'creation_time': datetime.datetime(2024, 10, 30, 17, 2, 56, 550522),
#      'file_size': 2.55})])}

# %%
found_pipeline_output_files_dict = {a_session_folder.context:get_pipeline_output_files(a_session_folder.context.session_name) for a_session_folder in good_session_concrete_folders}
found_pipeline_output_files_dict
# Out:
# {Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-08_14-26-15'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-08_14-26-15', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-08_14-26-15', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-08_14-26-15', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-08_14-26-15', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-08_14-26-15', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-08_14-26-15', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-09_1-22-43'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-09_1-22-43', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-09_1-22-43', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-09_1-22-43', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-09_1-22-43', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-09_1-22-43', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-09_1-22-43', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'one', session_name= '2006-6-12_15-55-31'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-12_15-55-31', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-12_15-55-31', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-12_15-55-31', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-12_15-55-31', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-12_15-55-31', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-12_15-55-31', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'two', session_name= '2006-6-07_16-40-19'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-07_16-40-19', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-07_16-40-19', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-07_16-40-19', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-07_16-40-19', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-07_16-40-19', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-07_16-40-19', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'two', session_name= '2006-6-08_21-16-25'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-08_21-16-25', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-08_21-16-25', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-08_21-16-25', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-08_21-16-25', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-08_21-16-25', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-08_21-16-25', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'two', session_name= '2006-6-09_22-24-40'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-09_22-24-40', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-09_22-24-40', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-09_22-24-40', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-09_22-24-40', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-09_22-24-40', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-09_22-24-40', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'gor01', exper_name= 'two', session_name= '2006-6-12_16-53-46'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-6-12_16-53-46', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-6-12_16-53-46', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-6-12_16-53-46', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-6-12_16-53-46', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-6-12_16-53-46', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-6-12_16-53-46', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'vvp01', exper_name= 'one', session_name= '2006-4-09_17-29-30'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-4-09_17-29-30', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-4-09_17-29-30', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-4-09_17-29-30', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-4-09_17-29-30', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-4-09_17-29-30', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-4-09_17-29-30', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'vvp01', exper_name= 'one', session_name= '2006-4-10_12-25-50'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-4-10_12-25-50', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-4-10_12-25-50', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-4-10_12-25-50', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-4-10_12-25-50', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-4-10_12-25-50', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-4-10_12-25-50', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'vvp01', exper_name= 'two', session_name= '2006-4-09_16-40-54'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-4-09_16-40-54', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-4-09_16-40-54', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-4-09_16-40-54', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-4-09_16-40-54', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-4-09_16-40-54', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-4-09_16-40-54', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'vvp01', exper_name= 'two', session_name= '2006-4-10_12-58-3'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='2006-4-10_12-58-3', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='2006-4-10_12-58-3', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='2006-4-10_12-58-3', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='2006-4-10_12-58-3', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='2006-4-10_12-58-3', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='2006-4-10_12-58-3', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'pin01', exper_name= 'one', session_name= '11-02_17-46-44'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='11-02_17-46-44', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='11-02_17-46-44', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='11-02_17-46-44', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='11-02_17-46-44', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='11-02_17-46-44', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='11-02_17-46-44', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'pin01', exper_name= 'one', session_name= '11-02_19-28-0'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='11-02_19-28-0', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='11-02_19-28-0', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='11-02_19-28-0', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='11-02_19-28-0', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='11-02_19-28-0', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='11-02_19-28-0', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'pin01', exper_name= 'one', session_name= '11-03_12-3-25'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='11-03_12-3-25', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='11-03_12-3-25', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='11-03_12-3-25', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='11-03_12-3-25', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='11-03_12-3-25', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='11-03_12-3-25', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>,
#  Context(format_name= 'kdiba', animal= 'pin01', exper_name= 'one', session_name= 'fet11-01_12-58-54'): <SessionFolderSpec: {'required_files': [], 'optional_files': [SessionFileSpec(fileSpecString='loadedSessPickle.pkl', suggestedBaseName='fet11-01_12-58-54', description='The entire computed pipeline', session_load_callback=None), SessionFileSpec(fileSpecString='{}.mua.npy', suggestedBaseName='fet11-01_12-58-54', description='Multi-Unit Acitivity Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.pbe.npy', suggestedBaseName='fet11-01_12-58-54', description='Population Burst Events Cache', session_load_callback=None), SessionFileSpec(fileSpecString='{}.interpolated_spike_positions.npy', suggestedBaseName='fet11-01_12-58-54', description='Position-interpolated spike info computed from the spike times and the positions', session_load_callback=None), SessionFileSpec(fileSpecString='{}.position.npy', suggestedBaseName='fet11-01_12-58-54', description='Interpolated position info with additional properties', session_load_callback=None), SessionFileSpec(fileSpecString='output/global_computation_results.pkl', suggestedBaseName='fet11-01_12-58-54', description='The global (across-epoch) computation functions computed results for the pipeline', session_load_callback=None)], 'additional_validation_requirements': []};>}

# %%
def render_single_file(file) -> str:
    """ renders a single file and potentially its size """
    leaf_str = ''
    if not isinstance(file, (tuple, list, dict)):
        leaf_str += f"'{file}'"
    else:
        ## handle multi-info files
        file_tuple = file
        assert len(file_tuple) == 2, f"file_tuple: {file_tuple}, len(file_tuple): {len(file_tuple)}"
        file, file_metadata_dict = file_tuple
        formatted_file_metadata_str: str = f"{file_metadata_dict['file_size']} GB"
        leaf_str += f"'{file}'\t{formatted_file_metadata_str}"
    return leaf_str


def render_tree(found_files_dict):
    tree_str = ""
    for session, (session_files, global_files) in found_files_dict.items():
        tree_str += f"{session}\n"
        if session_files:
            tree_str += "  - Session Pickle Files:\n"
            for file in session_files:
                leaf_str: str = render_single_file(file=file)
                tree_str += f"    * {leaf_str}\n"
        
        if global_files:
            tree_str += "  - Global Computation Results Files:\n"
            for file in global_files:
                leaf_str: str = render_single_file(file=file)
                tree_str += f"    * {leaf_str}\n"
    return tree_str

# Example of usage
tree_representation = render_tree(found_files_dict)
print(tree_representation)
# Out:
# kdiba_gor01_one_2006-6-08_14-26-15
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241105150345-loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].0-qclu_[1, 2, 4, 6, 7, 9].pkl'	0.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241107182055-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	2.45 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/20241108125129-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	2.37 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle.pkl'	4.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-09-26_GL.pkl'	4.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_2024-10-23_GL.pkl'	4.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	16.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	16.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	15.43 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	4.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	16.13 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	8.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl'	10.47 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	10.47 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results.pkl'	5.36 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-11_GL.pkl'	5.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-09-26_GL.pkl'	5.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_2024-10-23_GL.pkl'	5.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-09.pkl'	5.09 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_Pre2024-07-16.pkl'	5.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	5.12 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	5.12 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	5.01 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-08_14-26-15/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	4.81 GB
# kdiba_gor01_one_2006-6-09_1-22-43
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240710135946-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.38 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240715204503-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.37 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240716052924-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.37 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240717011236-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	9.75 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828173432-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	9.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240828225831-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829030301-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829064622-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20240829091715-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241107181515-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	6.27 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/20241108124734-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	6.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-11_GL.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-09-26_GL.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_2024-10-23_GL.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_Pre2024-07-09.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	9.63 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	9.61 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	14.28 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	10.07 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	13.74 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	4.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	14.4 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	14.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	9.64 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	9.62 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results.pkl'	5.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-11_GL.pkl'	5.13 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-09-26_GL.pkl'	5.13 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_2024-10-23_GL.pkl'	5.13 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-09.pkl'	4.91 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_Pre2024-07-16.pkl'	5.13 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	4.92 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	4.92 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	4.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-09_1-22-43/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	4.68 GB
# kdiba_gor01_one_2006-6-12_15-55-31
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle.pkl'	2.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-11_GL.pkl'	2.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-09-26_GL.pkl'	2.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_2024-10-23_GL.pkl'	2.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	2.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	5.41 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	4.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	5.18 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	2.15 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	5.49 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	5.52 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	2.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl'	3.61 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	2.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/outputs/loadedSessPickle.pkl'	0.3 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results.pkl'	1.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-11_GL.pkl'	0.07 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-09-26_GL.pkl'	0.07 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_2024-10-23_GL.pkl'	1.38 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-09.pkl'	1.46 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_Pre2024-07-16.pkl'	1.38 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.48 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	1.48 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	1.44 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/one/2006-6-12_15-55-31/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.37 GB
# kdiba_gor01_two_2006-6-07_16-40-19
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240705193651-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.0 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240706014544-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240708152121-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709011930-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240709025951-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.53 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240710135952-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.0 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240715205330-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	9.99 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20240716053230-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	10.0 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241107182153-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	5.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/20241108125422-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	5.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-11_GL.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-09-26_GL.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_2024-10-23_GL.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_Pre2024-07-16.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	14.67 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	14.67 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	14.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	5.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	14.75 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	8.59 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withOldestImportedReplays-qclu_??-frateThresh_0.1.pkl'	10.44 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	10.44 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/outputs/loadedSessPickle.pkl'	18.81 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results.pkl'	4.49 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_2024-09-11_GL.pkl'	4.45 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_2024-09-26_GL.pkl'	4.45 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_2024-10-23_GL.pkl'	4.45 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_Pre2024-07-09.pkl'	4.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_Pre2024-07-16.pkl'	4.45 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	4.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	4.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	4.18 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-07_16-40-19/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	3.99 GB
# kdiba_gor01_two_2006-6-08_21-16-25
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240710135349-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	8.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240715205952-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240716055345-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.87 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240717001652-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.68 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240828155730-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	7.89 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240828230940-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.86 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240829031121-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240829070005-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/20240829093340-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	8.86 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle.pkl'	3.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_2024-09-11_GL.pkl'	3.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_2024-09-26_GL.pkl'	3.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_Pre2024-07-09.pkl'	3.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_Pre2024-07-16.pkl'	3.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	7.17 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	7.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	9.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	9.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/outputs/loadedSessPickle.pkl'	4.52 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/output/global_computation_results.pkl'	3.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/output/global_computation_results_2024-09-11_GL.pkl'	3.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/output/global_computation_results_2024-09-26_GL.pkl'	3.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/output/global_computation_results_Pre2024-07-09.pkl'	3.43 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-08_21-16-25/output/global_computation_results_Pre2024-07-16.pkl'	3.55 GB
# kdiba_gor01_two_2006-6-09_22-24-40
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240706021314-loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.0.pkl'	2.43 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240708151429-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	2.84 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240709012533-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	3.24 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240709030515-loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.0.pkl'	3.05 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240710140228-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	3.64 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240715204707-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	3.64 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/20240716053053-loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.1.pkl'	3.64 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle.pkl'	5.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle_2024-09-11_GL.pkl'	5.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle_2024-09-26_GL.pkl'	5.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	1.52 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	12.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/loadedSessPickle_withOldestImportedReplays-qclu_XX-frateThresh_0.1.pkl'	12.18 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/outputs/loadedSessPickle.pkl'	0.89 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/output/global_computation_results.pkl'	5.89 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/output/global_computation_results_2024-09-11_GL.pkl'	5.87 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/output/global_computation_results_2024-09-26_GL.pkl'	5.87 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/output/global_computation_results_Pre2024-07-09.pkl'	5.63 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-09_22-24-40/output/global_computation_results_Pre2024-07-16.pkl'	5.87 GB
# kdiba_gor01_two_2006-6-12_16-53-46
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_2024-09-11_GL.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_2024-09-26_GL.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_2024-10-23_GL.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_Pre2024-07-16.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	4.43 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	3.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	4.2 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.56 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	4.5 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	4.53 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_2024-09-11_GL.pkl'	1.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_2024-09-26_GL.pkl'	1.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_2024-10-23_GL.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_Pre2024-07-09.pkl'	0.06 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_Pre2024-07-16.pkl'	1.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.38 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	1.38 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	1.35 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/gor01/two/2006-6-12_16-53-46/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.29 GB
# kdiba_vvp01_one_2006-4-09_17-29-30
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_2024-09-11_GL.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_2024-09-26_GL.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_2024-10-23_GL.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_Pre2024-07-09.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_Pre2024-07-16.pkl'	6.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	9.04 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	9.01 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	8.98 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	9.02 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/outputs/loadedSessPickle.pkl'	0.29 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_2024-09-11_GL.pkl'	1.42 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_2024-09-26_GL.pkl'	1.42 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_2024-10-23_GL.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_Pre2024-07-09.pkl'	1.29 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_Pre2024-07-16.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-09_17-29-30/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.31 GB
# kdiba_vvp01_one_2006-4-10_12-25-50
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle.pkl'	1.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_2024-09-11_GL.pkl'	1.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_2024-09-26_GL.pkl'	1.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_2024-10-23_GL.pkl'	1.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	4.7 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	4.67 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	4.79 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	4.79 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	4.61 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.96 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	4.85 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	4.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	4.67 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results.pkl'	1.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_2024-09-11_GL.pkl'	1.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_2024-09-26_GL.pkl'	1.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_2024-10-23_GL.pkl'	1.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_Pre2024-07-09.pkl'	1.14 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_Pre2024-07-16.pkl'	1.21 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.19 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	1.19 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	1.17 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/one/2006-4-10_12-25-50/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.12 GB
# kdiba_vvp01_two_2006-4-09_16-40-54
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/20241105150217-loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.0.pkl'	4.48 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_2024-09-11_GL.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_2024-09-26_GL.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_2024-10-23_GL.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_Pre2024-07-09.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_Pre2024-07-16.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	4.99 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	4.98 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	5.14 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	3.88 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	4.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	2.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	5.23 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	5.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	4.98 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/outputs/loadedSessPickle.pkl'	0.31 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results.pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_2024-09-11_GL.pkl'	1.32 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_2024-09-26_GL.pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_2024-10-23_GL.pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_Pre2024-07-09.pkl'	1.27 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_Pre2024-07-16.pkl'	1.32 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	1.3 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-09_16-40-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.24 GB
# kdiba_vvp01_two_2006-4-10_12-58-3
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_2024-09-11_GL.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_2024-09-26_GL.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_2024-10-23_GL.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_Pre2024-07-09.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_Pre2024-07-16.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	5.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	5.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	5.69 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	4.04 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	5.48 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	2.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	5.75 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	5.78 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	5.55 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/outputs/loadedSessPickle.pkl'	0.22 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results.pkl'	1.4 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_2024-09-11_GL.pkl'	1.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_2024-09-26_GL.pkl'	1.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_2024-10-23_GL.pkl'	1.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_Pre2024-07-09.pkl'	1.31 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_Pre2024-07-16.pkl'	1.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	1.36 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	1.36 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	1.33 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/vvp01/two/2006-4-10_12-58-3/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.29 GB
# kdiba_pin01_one_11-02_17-46-44
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle_2024-09-11_GL.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle_2024-09-26_GL.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle_Pre2024-07-09.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle_Pre2024-07-16.pkl'	2.93 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	6.89 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/output/global_computation_results.pkl'	1.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/output/global_computation_results_2024-09-11_GL.pkl'	1.71 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_17-46-44/output/global_computation_results_2024-09-26_GL.pkl'	1.71 GB
# kdiba_pin01_one_11-02_19-28-0
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle.pkl'	1.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_2024-09-11_GL.pkl'	1.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_2024-09-26_GL.pkl'	1.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_Pre2024-07-09.pkl'	1.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_Pre2024-07-16.pkl'	1.9 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_withNewComputedReplays-qclu_[1, 2]-frateThresh_5.0.pkl'	4.27 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_withNewKamranExportedReplays-qclu_[1,2]-frateThresh_5.0.pkl'	4.26 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	4.27 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/outputs/loadedSessPickle.pkl'	0.22 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/output/global_computation_results.pkl'	1.17 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/output/global_computation_results_2024-09-11_GL.pkl'	1.16 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/output/global_computation_results_2024-09-26_GL.pkl'	1.16 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/output/global_computation_results_Pre2024-07-09.pkl'	1.11 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-02_19-28-0/output/global_computation_results_Pre2024-07-16.pkl'	1.16 GB
# kdiba_pin01_one_11-03_12-3-25
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_2024-09-11_GL.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_2024-09-26_GL.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_2024-10-23_GL.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_Pre2024-07-09.pkl'	2.39 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_Pre2024-07-16.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	3.62 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	3.62 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	3.46 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	1.65 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	3.66 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	3.68 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/outputs/loadedSessPickle.pkl'	0.16 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results.pkl'	0.82 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-11_GL.pkl'	0.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-09-26_GL.pkl'	0.03 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_2024-10-23_GL.pkl'	0.82 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-09.pkl'	0.8 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_Pre2024-07-16.pkl'	0.82 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	0.86 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	0.86 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	0.84 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/11-03_12-3-25/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	0.81 GB
# kdiba_pin01_one_fet11-01_12-58-54
#   - Session Pickle Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle.pkl'	4.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-11_GL.pkl'	4.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-09-26_GL.pkl'	4.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_2024-10-23_GL.pkl'	4.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	10.57 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	10.57 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	10.09 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	4.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_1.0.pkl'	10.51 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1, 2, 4, 6, 7, 9]-frateThresh_5.0.pkl'	10.63 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/loadedSessPickle_withNormalComputedReplays-qclu_[1,2]-frateThresh_1.0.pkl'	10.19 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/outputs/loadedSessPickle.pkl'	0.32 GB
#   - Global Computation Results Files:
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results.pkl'	2.61 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-11_GL.pkl'	2.58 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-09-26_GL.pkl'	2.58 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_2024-10-23_GL.pkl'	2.58 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-09.pkl'	2.64 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_Pre2024-07-16.pkl'	2.58 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9].pkl'	2.73 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2, 4, 6, 7, 9]_Pre2024-07-16.pkl'	2.73 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2].pkl'	2.6 GB
#     * '/nfs/turbo/umms-kdiba/KDIBA/pin01/one/fet11-01_12-58-54/output/global_computation_results_withNormalComputedReplays-frateThresh_5.0-qclu_[1, 2]_Pre2024-07-16.pkl'	2.55 GB

# %%
import ipywidgets as widgets

def create_tree_view(found_files_dict):
    sessions_accordion = widgets.Accordion(children=[widgets.VBox() for _ in found_files_dict])
    for i, (session, (session_files, global_files)) in enumerate(found_files_dict.items()):
        session_accordion = sessions_accordion.children[i]
        
        # Convert paths to strings and create session pickle files accordion
        session_files_accordion = widgets.Accordion(children=[
            widgets.VBox([widgets.Label(str(file)) for file in session_files])
        ])
        session_files_accordion.set_title(0, 'Session Pickle Files')

        # Convert paths to strings and create global computation results files accordion
        global_files_accordion = widgets.Accordion(children=[
            widgets.VBox([widgets.Label(str(file)) for file in global_files])
        ])
        global_files_accordion.set_title(0, 'Global Computation Results Files')

        # Set session accordion children
        session_accordion.children = [session_files_accordion, global_files_accordion]
        
        # Set main accordion title
        sessions_accordion.set_title(i, str(session))

    return sessions_accordion

# Example usage
tree_view = create_tree_view(found_files_dict)
tree_view
# Out:
# Accordion(children=(VBox(children=(Accordion(children=(VBox(children=(Label(value="(PosixPath('/nfs/turbo/umms…

# %%
search_parent_path = Path(r'W:\\Data\\Kdiba')
# search_parent_path = Path(r'/home/halechr/turbo/Data/KDIBA').resolve() # Greatlakes
# search_parent_path = Path(r'/home/halechr/cloud/turbo/Data/KDIBA').resolve() # Lab

# found_autoversioned_session_pickle_files = discover_data_files(search_parent_path, glob_pattern='*-loadedSessPickle.pkl', recursive=True)
# found_global_computation_results_files = discover_data_files(search_parent_path, glob_pattern='output/*.pkl', recursive=True)


found_any_kind_session_pickle_files = discover_data_files(search_parent_path, glob_pattern='*loadedSessPickle*.pkl', recursive=True)
found_any_global_computation_results_files = discover_data_files(search_parent_path, glob_pattern='output/*global_computation_results*.pkl', recursive=True)

# found_session_pickle_files = discover_data_files(source_data_root, glob_pattern='loadedSessPickle.pkl', recursive=True)
# found_global_computation_results_files = discover_data_files(source_data_root, glob_pattern=f'output/{completed_global_computations_filename}', recursive=True)

found_files = found_any_global_computation_results_files + found_any_kind_session_pickle_files

found_files_metadata = [get_file_metadata(f) for f in found_files]

# found_files_metadata_dict = {f:get_file_metadata(f) for f in found_files}

# found_files
# found_files_metadata_dict
found_files_metadata

pd.DataFrame.from_records(found_files_metadata)

# %% [markdown]
# # 2023-11-20 - Discovery of folder modification times from matching files

# %%
Write a python function that

# %%
def determine_directory_modification_time(target_

# %% [markdown]
# # 2024-06-11 - Listing Pickle Contents without Loading everything

# %%
# found_session_pickle_files
_test_pickle_dir = Path(r"W:\Data\KDIBA\gor01\one\2006-6-12_15-55-31\loadedSessPickle.pkl").resolve()
_test_global_pickle_dir = Path(r"W:\Data\KDIBA\gor01\one\2006-6-12_15-55-31\output\global_computation_results.pkl").resolve()

assert _test_pickle_dir.exists()
assert _test_global_pickle_dir.exists()

# %%
from pyphoplacecellanalysis.General.Pipeline.Stages.Loading import loadData
from pyphocorehelpers.print_helpers import DocumentationFilePrinter, TypePrintMode, print_keys_if_possible, debug_dump_object_member_shapes, print_value_overview_only, document_active_variables

_out = loadData(pkl_path=_test_pickle_dir, debug_print=False) # <pyphoplacecellanalysis.General.Pipeline.NeuropyPipeline.NeuropyPipeline at 0x1f5e627c670>
_out

# %%
print_keys_if_possible(curr_key='pipeline', curr_value=_out, max_depth=2)
