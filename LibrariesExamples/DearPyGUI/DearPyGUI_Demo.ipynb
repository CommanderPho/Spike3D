# %%
import dearpygui.dearpygui as dpg
from dearpygui.demo import show_demo

dpg.create_context()
dpg.create_viewport()
dpg.setup_dearpygui()

show_demo()

dpg.show_viewport()
dpg.start_dearpygui()
dpg.destroy_context()
# Out:
# sender: 102, 	 app_data: None, 	 user_data: None
# sender: 103, 	 app_data: None, 	 user_data: None
# sender: 104, 	 app_data: None, 	 user_data: None
# sender: 108, 	 app_data: True, 	 user_data: None
# sender: 108, 	 app_data: False, 	 user_data: None
# sender: 143, 	 app_data: None, 	 user_data: None
# sender: 151, 	 app_data: None, 	 user_data: None
# sender: 178, 	 app_data: DDDD, 	 user_data: None
# sender: 187, 	 app_data: 0.10000000149011612, 	 user_data: None
# sender: 189, 	 app_data: 1, 	 user_data: None
# sender: 189, 	 app_data: 4, 	 user_data: None
# sender: 189, 	 app_data: 7, 	 user_data: None
# sender: 189, 	 app_data: 11, 	 user_data: None
# sender: 189, 	 app_data: 14, 	 user_data: None
# sender: 189, 	 app_data: 17, 	 user_data: None
# sender: 189, 	 app_data: 18, 	 user_data: None
# sender: 189, 	 app_data: 19, 	 user_data: None
# sender: 189, 	 app_data: 20, 	 user_data: None
# sender: 189, 	 app_data: 21, 	 user_data: None
# ...
